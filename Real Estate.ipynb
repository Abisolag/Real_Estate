# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas project
# 1. Using Real Estate Dataset, remove redundant data
# 2. Find the total sales by Residential Type
# 3. Generate a new table that sort your data using column Sales Ratio from the highest to the minimum
# 4. Find the first 10 Sales with the highest amount in a dataframe
# 5. Return the min, the max and the total sales of Estate
# 6. Congratulations on your new job as a data analyst in a Real Estate company, we realize that as years goes by, we are begining to experience changes in our sales, can you draw a conclusion for your new employer, the effect of time on the company sales?
# 7. Kindly advise the company, which town should they stop selling Estate
# 8. Base on your findings, advise the company, which town should we continue selling our Real Estate
# 9. We have different properties in our company, which property will you advise us to stop selling and which will you advise us to sell more of it?
# SAVE YOUR ANALYSIS WITH YOUR NAME AND YOUR STUDENT'S ID. GOODLUCK...

# %%
#To import the real estate dataset
data=pd.read_csv('Real_Estate_Sales_2001-2020_GL.csv')
data
# Out:
# C:\Users\victoria\AppData\Local\Temp\ipykernel_7732\3639444233.py:2: DtypeWarning: Columns (8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('Real_Estate_Sales_2001-2020_GL.csv')
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# ...

# %%
data.drop(['Non Use Code', 'Assessor Remarks','OPM remarks', 'Location'], axis=1, inplace=True)
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
data.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type'],
#       dtype='object')

# %%
Data=data['Residential Type'].fillna('Unknown', inplace=True)

# %%
Data1=data['Property Type'].fillna('Unknown',inplace=True)
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
data[data['Town']=="***Unknown***"]
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 444657          70086       2007    12/18/2007  ***Unknown***
#
#                 Address  Assessed Value  Sale Amount  Sales Ratio  \
# 444657  18 MATHIEU LANE         66540.0     282450.0     0.235582
#
#         Property Type Residential Type
# 444657  Single Family    Single Family

# %%
data.drop(index=444657, axis=0, inplace=True)

# %%
data.info
# Out:
# <bound method DataFrame.info of         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# ...

# %%
data = data[(data['Assessed Value'] > 10.0) & (data['Sale Amount'] > 100.0)]

# %%
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
data['Profit']=data['Sale Amount']- data['Assessed Value']
data['Profit']
# Out:
# C:\Users\victoria\AppData\Local\Temp\ipykernel_7732\3261460171.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Profit']=data['Sale Amount']- data['Assessed Value']
# 0          174500.0
# 1          177000.0
# 2           49500.0
# 3          270710.0
# 4          585170.0
#             ...
# 997208      -7310.0
# 997209       7720.0
# 997210      88550.0
# 997211      76640.0
# 997212    3414030.0
# Name: Profit, Length: 988644, dtype: float64

# %%
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %% [markdown]
# # Find the total sales by Residential Type

# %%
data.groupby('Residential Type')[['Sale Amount']].sum()
# Out:
#                    Sale Amount
# Residential Type
# Condo             3.207560e+10
# Four Family       7.615052e+08
# Single Family     1.781615e+11
# Three Family      2.868037e+09
# Two Family        6.125448e+09
# Unknown           1.677756e+11

# %% [markdown]
# From the result drawn, it can be observed that Residential type[Unknown] has the highest Sales amount. However, we cannot generalize our conclusion with this result, hence dataset is subject to further analysis.

# %%
#replace all unknown columns with NAN and drop all NAN
data.replace('Unknown', np.nan, inplace=True)
# Out:
# C:\Users\victoria\AppData\Local\Temp\ipykernel_7732\3349181920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.replace('Unknown', np.nan, inplace=True)

# %%
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %%
data.dropna(axis=0, inplace= True)
# Out:
# C:\Users\victoria\AppData\Local\Temp\ipykernel_7732\2283914991.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(axis=0, inplace= True)

# %%
data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# 5              200109       2020    12/09/2020           Avon
# ...               ...        ...           ...            ...
# 997207         190272       2019    08/03/2020         Wilton
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# 2            5 CHESTNUT DRIVE        130400.0     179900.0     0.724800
# ...

# %% [markdown]
# # Generate a new table that sort your data using column Sales Ratio from the highest to the minimum

# %%
new_data=data.sort_values("Sales Ratio", ascending=False)
new_data
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 528256          90429       2009    05/05/2010      Greenwich
# 870743         170276       2017    01/09/2018      Stratford
# 874177         170277       2017    01/09/2018      Stratford
# 386502          60092       2006    01/30/2007     New Canaan
# 822121         160815       2016    06/27/2017      Stratford
# ...               ...        ...           ...            ...
# 457535          60141       2006    01/05/2007  South Windsor
# 453243          60042       2006    11/15/2006   Old Saybrook
# 638965         110002       2011    11/03/2011          Union
# 51999         2000797       2020    01/15/2021       Stamford
# 38045         2000798       2020    01/15/2021       Stamford
#
#                             Address  Assessed Value  Sale Amount  Sales Ratio  \
# 528256        38 FRENCH ROAD,GRW,CT       6320090.0       3000.0  2106.696667
# ...

# %% [markdown]
# # Find the first 10 Sales with the highest amount in a dataframe

# %%
sales=data.sort_values('Sale Amount', ascending=False).head(10)
sales
# Out:
#         Serial Number  List Year Date Recorded        Town  \
# 60894        20200078       2020    07/06/2021  Willington
# 65620        20200102       2020    09/28/2021  Willington
# 957543         191094       2019    08/12/2020     Norwalk
# 655816         130446       2013    04/11/2014   Greenwich
# 38490         2000804       2020    01/15/2021    Stamford
# 44648         2000818       2020    01/15/2021    Stamford
# 38045         2000798       2020    01/15/2021    Stamford
# 28506         2000814       2020    01/15/2021    Stamford
# 29966         2000808       2020    01/15/2021    Stamford
# 44353         2000800       2020    01/15/2021    Stamford
#
#                             Address  Assessed Value  Sale Amount  Sales Ratio  \
# 60894                224 RIVER ROAD        223070.0  318790019.0     0.000700
# 65620       7 TOLLAND TURNPIKE ROAD        112040.0  194149073.0     0.000577
# 957543                33 ORCHARD ST        507580.0  157000000.0     0.003200
# ...

# %% [markdown]
# # Return the min, the max and the total sales of Estate

# %%
mi=data['Sale Amount'].min()
mi
# Out:
# 487.0

# %%
mx=data['Sale Amount'].max()
mx
# Out:
# 318790019.0

# %%
sm=data['Sale Amount'].sum()
sm
# Out:
# 219991132959.16003

# %% [markdown]
# #  The effect of time on the company sales?

# %%
data.groupby('List Year')[['Sale Amount']].corr(method='pearson')
# Out:
#                        Sale Amount
# List Year
# 2006      Sale Amount          1.0
# 2007      Sale Amount          1.0
# 2008      Sale Amount          1.0
# 2009      Sale Amount          1.0
# 2010      Sale Amount          1.0
# 2011      Sale Amount          1.0
# 2012      Sale Amount          1.0
# 2013      Sale Amount          1.0
# 2014      Sale Amount          1.0
# 2015      Sale Amount          1.0
# 2016      Sale Amount          1.0
# 2017      Sale Amount          1.0
# 2018      Sale Amount          1.0
# 2019      Sale Amount          1.0
# 2020      Sale Amount          1.0

# %% [markdown]
# # Kindly advise the company, which town should they stop selling Estate

# %%
data.groupby('Town')['Profit'].sum().sort_values()
# Out:
# Town
# Hamden      -3.924547e+08
# Union        9.921670e+06
# Colebrook    1.043955e+07
# Scotland     1.308905e+07
# Hartland     1.496502e+07
#                  ...
# Darien       2.498747e+09
# Norwalk      2.644640e+09
# Westport     2.736571e+09
# Stamford     4.634990e+09
# Greenwich    5.885154e+09
# Name: Profit, Length: 169, dtype: float64

# %% [markdown]
# Base on the result drawn, it can be observed that there is a loss in sales at Hamden with a depricating value of -3.924547e+08. Hence sales should stop at Hamden Town

# %% [markdown]
# # Base on your findings, advise the company, which town should we continue selling our Real Estate

# %% [markdown]
# From the result gotten, it can be observed that Greenwitch had the highest profit, hence, it can be concluded that sales shoul increase at GREENWICH Town

# %% [markdown]
# # We have different properties in our company, which property will you advise us to stop selling and which will you advise us to sell more of it?

# %%
data.groupby('Property Type')['Profit'].sum().sort_values()
# Out:
# Property Type
# Four Family      2.757671e+08
# Three Family     5.426211e+08
# Two Family       1.225381e+09
# Condo            8.520186e+09
# Residential      1.145608e+10
# Single Family    4.457661e+10
# Name: Profit, dtype: float64

# %%
It can be concluded that sales should
